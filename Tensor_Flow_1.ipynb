# %% [markdown]
# <a href="https://colab.research.google.com/github/minette3762/numpde/blob/main/Tensor_Flow_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
X = np.random.rand(N)
Y = 5*X+10+0.4*np.random.rand(N)
plt.plot(X,Y,'.')
plt.show()

# %%
W = np.random.rand()
b = np.random.rand()

W = tf.Variable(W)
b = tf.Variable(b)
lr = 0.1

for epoch in range(1000):
  with tf.GradientTape() as t:
    y = W*X+b
    loss = tf.reduce_mean((y-Y)**2)
  dW,db = t.gradient(loss,[W,b])
  W.assign_sub(lr*dW)
  W.assign_sub(lr*db)
  print(epoch,W.numpy(),b.numpy(),loss.numpy())
# Out:
# 0 4.2053466 0.30517617 148.77736
# 1 7.297352 0.30517617 105.82293
# 2 9.876432 0.30517617 76.995384
# 3 12.027677 0.30517617 57.821095
# 4 13.822058 0.30517617 45.21662
# 5 15.318774 0.30517617 37.060978
# 6 16.567205 0.30517617 31.89876
# 7 17.608538 0.30517617 28.73426
# 8 18.477127 0.30517617 26.888813
# 9 19.201628 0.30517617 25.901995
# 10 19.805943 0.30517617 25.463274
# 11 20.310009 0.30517617 25.36477
# 12 20.730457 0.30517617 25.468674
# 13 21.08116 0.30517617 25.684803
# 14 21.373684 0.30517617 25.955147
# 15 21.617683 0.30517617 26.243305
# 16 21.821207 0.30517617 26.527266
# 17 21.990967 0.30517617 26.79445
# 18 22.132566 0.30517617 27.038418
# 19 22.250677 0.30517617 27.256601
# 20 22.349194 0.30517617 27.448803
# 21 22.431368 0.30517617 27.616228
# 22 22.49991 0.30517617 27.760826
# 23 22.557083 0.30517617 27.884878
# 24 22.604773 0.30517617 27.990746
# 25 22.64455 0.30517617 28.080715
# 26 22.677729 0.30517617 28.15692
# 27 22.705404 0.30517617 28.221289
# ...

# %%
Z  = W*X+b
plt.plot(X,Y,'.')
plt.plot(X,Z,'.r')
